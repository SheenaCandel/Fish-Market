# %%
from IPython.display import HTML

HTML('''<script>
  code_show=true;
  function code_toggle() {
    if (code_show){
      $('div.input').hide();
    } else {
      $('div.input').show();
    }
    code_show = !code_show
  }
  $( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Toggle code on/off"></form>''')
# Out:
# <script>
#   code_show=true;
#   function code_toggle() {
#     if (code_show){
#       $('div.input').hide();
#     } else {
#       $('div.input').show();
#     }
#     code_show = !code_show
#   }
#   $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Toggle code on/off"></form>

# %% [markdown]
# ## Machine Learning Group Project

# %% [markdown]
# In Partial Fulfillment Of The Requirements for the Subject Machine Learning 1
#
# Notebook Prepared by: </br>
#     **Candel, Sheena** </br>
# 	**Hilotin, Tessa Mae**</br>
# 	**Javier, Alexandria**</br>
# 	**Llamis, Charlyn**</br>
#
# University of Science and Technology of Southern Philippines </br>
# C.M. Recto Ave., Lapasan, Cagayan de Oro City, Philippines

# %% [markdown]
# # Fish Market EDA and Machine Learning Models

# %% [markdown]
# ### Executive Summary

# %% [markdown]
# Aside from other seafood and essential foods, fish is one of the items sold in a market. It has always been a valuable resource for humanity, primarily as a food source. They are mostly found in the sea, rivers, oceans, and even lakes. Fish have approximately 35,000 species worldwide, the most species diversity of any vertebrate group of various sizes and shapes. The price of a fish in a fish market is usually determined by the type of fish (or species), its weight, height, and length.
#
# In this project, we will determine the seven most common fish species in fish market sales. Bream, Parkki, Perch, Pike, Roach, Smelt, and Whitefish are among the species. They are fairly common in Finland. The dataset includes fish weight in Gram g and length in various lengths such as vertical length, diagonal length, cross length, and height. With this dataset, a predictive model can be performed using machine-friendly data to estimate fish weight. Using "weight" dependent variable and 'species', different lengths', 'height' and 'width' as the independent variables.
#
# The Exploratory Data Analysis is applied to properly visualize the results of the data and their correlation to each other for the better fit of the model. Finally, we will use different machine learning models to explore the best accuracy that will fit for the dataset and in order to use the best machine learning models.

# %% [markdown]
# ### Introduction

# %% [markdown]
# In the fish market, it is critical to accurately identify the price of the fish, and two major factors that influence the price are fish species and weight. The goal of this project is to forecast the weight of a fish based on its length, height, and width, as well as categorize fish species based on their weight, length, width and height. We would show a simple machine learning forecast (using linear regression) based on the information we gathered, as weight is often the determinant of fish price (or earning).
#
# Fish markets range in size from small fish stalls, medium and large depending on the demand. In the fish market, it is important to determine the price of the fish correctly, and 2 important factors that impact on the price are fish species and also the weight. Different species of fish and uses their cross-length and volume to find correlations in weight among the different fish. The different types of fish that we compare include perch, pike, parkki, whitefish, bream, roach, and smelt.
#
# This dataset is a record of 7 common different fish species in fish market sales. Mainly the:
#
# <table>
# <thead>
# <tr><th>Species</th><th></th>
# </thead>
# <tbody>
# <tr><td>Bream</td><td>a common European food and game fish of the carp family, Cyprinidae, found in lakes and slow rivers. It is deep bodied, with flat sides and a small head, and is silvery with a bluish or brown back. Length is usually about 30–50 centimetres (12–20 inches), weight to 6 kilograms (13 pounds).</td></tr>
# <tr><td>Roach</td><td> common European sport fish of the carp family, Cyprinidae, widely distributed in lakes and slow rivers. A high-backed, yellowish green fish with red eyes and reddish fins, the roach is about 15–40 cm (6–16 inches) long and weighs up to 2 kg (4 1/2 pounds). It lives in small schools and eats aquatic plants, insects, and other small animals.</td></tr>
# <tr><td>Whitefish</td><td>a freshwater silvery, small-mouthed, are in the family Salmonidae. Though related to salmon and trout, they have pure-white meat and are traditionally the species used for gefilte fish. Whitefish roe, marketed as golden caviar, is highly valued. Because whitefish are harvested from cold, northern waters and are not subjected to climatic heat, the quality is generally quite good.</td></tr>
# <tr><td>Perch</td><td>a greenish with dark, vertical bars on the sides and reddish or orange colouring in the lower fins. It grows to a maximum weight of about 3 kg (6 pounds), rarely more. The yellow perch, native to eastern North America and introduced on the Pacific coast, is similar to the European perch but yellower in colour. It grows to about 40 cm (15 inches) and 1 kg (2.2 pounds).</td></tr>
# <tr><td>Pike</td><td>which has a bean-shaped spots on the body and lacks scales on the lower parts of the gill covers. It is a fairly common and prized game fish with a maximum size and weight of about 1.4 metres (4.5 feet) and 21 kilograms (46 pounds).</td></tr>
# <tr><td>Smelt</td><td>fish has been introduced from the Atlantic Ocean to the Great Lakes and supports a sizable commercial fishery. The largest smelt, about 37.5 cm (15 inches) long, spawns in late winter or spring, its sticky eggs adhering to objects they touch.</td></tr>
# <tr><td>Parkki</td><td>One of the small fishes where Telugu people call it as Pakkilu</td></tr>
#
# </tbody>
# </table>

# %% [markdown]
# Feature Definition of the **7 common different fish species** in fish market sales.
#
# <table>
# <thead>
# <tr><th>Features</th><th></th>
# </thead>
# <tbody>
# <tr><td>Weight</td><td>Weight of the Fish in grams
# </td></tr>
# <tr><td>Length1</td><td>Vertical length of the Fish in centimeters
# </td></tr>
# <tr><td>Length2</td><td>Diagonal length of the Fish in centimeters
#
# </td></tr>
# <tr><td>Length3</td><td>Cross length of the Fish in centimeters
# </td></tr>
# <tr><td>Height</td><td>Height of the Fish in centimeters
# </td></tr>
# <tr><td>Width</td><td>Diagonal width of the Fish in centimeters
# </td></tr>
#
# </tbody>
# </table>

# %% [markdown]
# ### Problem Statement and Objective

# %% [markdown]
# **Problem Statement:**
#
# Why the consumer prefers to buy this type of fish? What is the species of the fish? Without using weighing scale, what would be the weight of the fish? That is what we are going to find out using Classification and Regression.
#
#
# **Objective:**
#
# The main objective in this project is to determine fish price according to its:
#
# 1. Fish Species/Type and its Weight.
# 2.  ML model of the fish’s weight based on the length, height and width of the fish and also to classify fish’s species based on the weight, length, width and height.

# %% [markdown]
# ### Methodology

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <h1 style="font size: 30px; color:#7bb661; align: center; text-shadow: 2px 2px #3B3B38;">DATA PROCESSING </h1>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Fish.csv')

data.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col1 {
#             background-color:  #fdcdac;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col2 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col3 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col4 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col5 {
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow0_col6 {
#             background-color:  #f4cae4;
#             color:  #000000;
#         }    #T_86147cc2_ec8e_11ec_9e7f_b86b23afe38crow1_col1 {
#             background-color:  #fdcdac;
#             color:  #000000;
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# ### Rename some column names

# %%
a=data
a.rename(columns={'Length1': 'Vertical_Length'}, inplace=True)
a.rename(columns={'Length2': 'Diagonal_Length'}, inplace=True)
a.rename(columns={'Length3': 'Cross_Length'}, inplace=True)
a.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col1 {
#             background-color:  #fdcdac;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col2 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col3 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col4 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col5 {
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow0_col6 {
#             background-color:  #f4cae4;
#             color:  #000000;
#         }    #T_8685b922_ec8e_11ec_809c_b86b23afe38crow1_col1 {
#             background-color:  #fdcdac;
#             color:  #000000;
# ...

# %%
data["Species"].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %% [markdown]
# ### Looking for 0 Values

# %%
data.isnull().sum()
# Out:
# Species            0
# Weight             0
# Vertical_Length    0
# Diagonal_Length    0
# Cross_Length       0
# Height             0
# Width              0
# dtype: int64

# %%
for col in data.columns:
    print("The minimum value for the columns {} is {}".format(col, data[col].min()))
# Out:
# The minimum value for the columns Species is Bream
# The minimum value for the columns Weight is 0.0
# The minimum value for the columns Vertical_Length is 7.5
# The minimum value for the columns Diagonal_Length is 8.4
# The minimum value for the columns Cross_Length is 8.8
# The minimum value for the columns Height is 1.7284
# The minimum value for the columns Width is 1.0476

# %% [markdown]
# ### Data Imputation

# %%
#Filtering Data
b=data[(data['Species'] == 'Roach') & (data['Vertical_Length'] <= 20)]

b.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col1 {
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col2 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col3 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col4 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col5 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow0_col6 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86aff289_ec8e_11ec_9f6a_b86b23afe38crow1_col1 {
#             background-color:  #e6f5c9;
#             color:  #000000;
# ...

# %% [markdown]
# Since weight is usually affected by length, we'll replace the zero value with the closest Roach's length

# %%
data.iloc[[40]] = data.iloc[[40]].replace({0.0 : 120})
b=data.iloc[[40]]
b.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col1 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col2 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col3 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col4 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col5 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86bb3b85_ec8e_11ec_a041_b86b23afe38crow0_col6 {
#             background-color:  #b3e2cd;
#             color:  #000000;
# ...

# %%
c=data[(data['Species'] == 'Roach') & (data['Vertical_Length'] <= 20)]
c.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col1 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col2 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col3 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col4 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col5 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow0_col6 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86c60f53_ec8e_11ec_92a6_b86b23afe38crow1_col1 {
#             background-color:  #cbd5e8;
#             color:  #000000;
# ...

# %% [markdown]
# <h1 style="font-size: 30px; color:#7bb661; align: center; text-shadow: 2px 2px #3B3B38;">DATA EXPLORATION </h1>

# %%
d=data.groupby('Species').mean().round(2)

d.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col0 {
#             background-color:  #f1e2cc;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col1 {
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col2 {
#             background-color:  #fff2ae;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col3 {
#             background-color:  #fff2ae;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col4 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow0_col5 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_86d46518_ec8e_11ec_a6fe_b86b23afe38crow1_col0 {
#             background-color:  #fdcdac;
#             color:  #000000;
# ...

# %%
e=data[(data['Weight'] == data['Weight'].max()) | (data['Weight'] == data['Weight'].min())]

e.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col1 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col2 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col3 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col4 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col5 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow0_col6 {
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }    #T_86de75b6_ec8e_11ec_8f99_b86b23afe38crow1_col1 {
#             background-color:  #cccccc;
#             color:  #000000;
# ...

# %%
sns.countplot(data['Species'], palette='rainbow')
plt.text(s="Popular Choice of Fish in the Market",x=3,y=65, fontsize=25,va='bottom',ha='center', color = '#a81c07')
plt.show()

# %%
features = ['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt']
sizes = [data.Species[data['Species'] == 'Bream'].count(), data.Species[data['Species'] == 'Roach'].count(),
         data.Species[data['Species'] == 'Whitefish'].count(), data.Species[data['Species'] == 'Parkki'].count(),
         data.Species[data['Species'] == 'Perch'].count(), data.Species[data['Species'] == 'Pike'].count(),
         data.Species[data['Species'] == 'Smelt'].count()]
hue = ['#07689F', '#34656D','#29BB89','#3797A4','#FCF876','#00A19D','#00A19D']
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(sizes, labels = features, colors = hue,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Species Proportion', size = 20, color = '#005142')
plt.show()

# %% [markdown]
# ### Observations:
#
# The first table shows the mean value of `Wegiht`, `Height`, `Width`, and different `Length` in every `Species` available in the market. We can observe that the average weight of all species Pike is the heaviest for at least 718.71g the lighest is Smelt around 11 g. On the other hand, Pike species has the longest average length particularly in its vertical length while Smelt sprecies is the shortest. This goes to their diagonal lenght and cross lenght  with a slight difference of mean value to the vertical length.
#
# It can be observed that `Perch` is the most popular choice in the Market since it is the highest count among the rest for around 35% of the dataset while `Whitefish` is the least around 3% of the dataset.

# %%
sns.barplot(x = data['Species'], y = data['Weight'], palette='CMRmap_r')
plt.text(s="Weight Analysis",x=3,y=1080, fontsize=25,va='bottom',ha='center', color = '#002e63')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Weight'],palette='CMRmap_r')
plt.show()
plt.close()

# %% [markdown]
# ### Weight Analysis
#
# Barplot shows the result of the heaviest weight among different species. `Bream`, `Whitefish` and `Pike` is the top 3 heaviest species. We can observe that in `Perch` species there are plenty of it weighed around 250g compared to heavier mass as well as the `Roach` species.

# %%
sns.barplot(x = data['Species'], y = data['Vertical_Length'], palette='terrain')
plt.text(s="Vertical Length Analysis",x=3,y=52, fontsize=25,va='bottom',ha='center', color = '#65000b')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Vertical_Length'],palette='terrain')
plt.show()
plt.close()

# %% [markdown]
# ### Vertical Length Analysis
# The first graph shows the result of the longest vertical length species. Among the others `Pike` is the longest while `Smelt` is the shortest. `Parki` and `Roach` are almost identical as well as `beam` and `whitefish`. We can observe that most of `Bream` species' height are around 27cm to 39 cm.

# %%
sns.barplot(x = data['Species'], y = data['Diagonal_Length'], palette='twilight_r')
plt.text(s="Diagonal Length Analysis",x=3,y=55, fontsize=25,va='bottom',ha='center', color = '#5d3954')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Diagonal_Length'],palette='twilight_r')
plt.show()
plt.close()

# %%
sns.barplot(x = data['Species'], y = data['Cross_Length'], palette='Set1_r')
plt.text(s="Cross Length Analysis",x=3,y=57, fontsize=25,va='bottom',ha='center', color = '#3d0c02')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Cross_Length'],palette='Set1_r')
plt.show()
plt.close()

# %% [markdown]
# ### Cross and Diagonal Length Analysis
#
# Cross and Diagonal length has the same results to Vetrical length. However, there are slight difference to their height.

# %%
sns.barplot(x = data['Species'], y = data['Width'], palette='Paired')
plt.text(s="Width Analysis",x=3,y=7, fontsize=25,va='bottom',ha='center', color = '#b31b1b')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Width'],palette='Paired')
plt.show()
plt.close()

# %% [markdown]
# ### Width Analysis
#
# We can observe that `Bream` and `Whitefish` are almost identical to its average width. Both of them are the highest capacity of width among the others.

# %%
sns.barplot(x = data['Species'], y = data['Height'], palette='Paired_r')
plt.text(s="Height Analysis",x=3,y=18, fontsize=25,va='bottom',ha='center', color = '#191970')
plt.show()
plt.close()

sns.stripplot(x = data['Species'], y = data['Height'],palette='Paired_r')
plt.show()
plt.close()

# %% [markdown]
# ### Height Analysis
#
# It is visisble that `Bream` has the tallest height while `Smelt` is the shortest.

# %%
sns.pairplot(data, hue = 'Species', palette = 'rainbow')

# %% [markdown]
# The pairplot above shows a strong positive correlation. We want to estimate the `Weight` of the fish to different features so we need to identify the features that correlates to the `Weight`. Fortunately `Weight` correlates to every feature available.

# %% [markdown]
# ### Objective

# %% [markdown]
# <h1 style="font size: 30px; color:#7bb661; align: center; text-shadow: 2px 2px #3B3B38;">MACHINE LEARNING </h1>

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### Linearn Regression without L1 & L2

# %%
# we want to estimate the relationship between two
df_bream = data[data['Species'] == 'Bream']

from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()

X = df_bream.Cross_Length.values.reshape(-1,1)
y = df_bream.Weight.values.reshape(-1,1)

linear_reg.fit(X,y)
y_head = linear_reg.predict(X)

plt.scatter(df_bream.Cross_Length,df_bream.Weight)
plt.plot(X,y_head,color= "red", linestyle=':')
plt.xlabel("Total Length")
plt.ylabel("Weight")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('y = ' + str('%.2f' % LR.intercept_) + ' + ' + str
      ('%.2f' % LR.coef_[0]) + '*X1 ' + ' + ' + str('%.2f' % LR.coef_[0]) + '*X2 ')
# Out:
# y = -1133.63 + 45.60*X1  + 45.60*X2

# %%
print("training set score: R2 = %f" % LR.score(X_train, y_train))
print("test set score: R2 = %f" % LR.score(X_test, y_test))
# Out:
# training set score: R2 = 0.938842
# test set score: R2 = 0.826496

# %% [markdown]
# ####  With L2-Ridge Regression

# %%
plt.figure(figsize=(5.5, 5))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
y_pred_train=LR.predict(X_train)
plt.plot(y_train,y_pred_train, 'o')
plt.xlim(0, max(y_train)+5 )
plt.ylim(0, max(y_train) +5)
plt.ylabel("Linear Regression Prediction: Training", fontsize=18)
plt.xlabel("Actual Target Value: Training",fontsize=18)
print("R^2 = %0.2f" % LR.score(X_train, y_train))
# Out:
# R^2 = 0.94

# %% [markdown]
# ##### Beam and Weight

# %%
df_bream = data[data['Species'] == 'Bream']

from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()

X = df_bream.Cross_Length.values.reshape(-1,1)
y = df_bream.Weight.values.reshape(-1,1)

# %%
from sklearn.linear_model import Ridge
#How much importance the model places on simplicity versus training 
#set performance can be specified by the user, using the alpha parameter
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
ridge = Ridge(alpha=0.001).fit(X_train, y_train)
print("training set score: %f" % ridge.score(X_train, y_train))
print("test set score: %f" % ridge.score(X_test, y_test))
# Out:
# training set score: 0.938842
# test set score: 0.826495

# %% [markdown]
# ##### Using all features

# %%
feature_names = ['Weight','Vertical_Length','Diagonal_Length','Cross_Length','Height','Width']
x = data[feature_names]
y = data['Species']
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.35, random_state=42)

logisticregression = LogisticRegression(C=100).fit(x_train, y_train)
print("training set score: %f" % logisticregression.score(x_train, y_train))
print("test set score: %f" % logisticregression.score(x_test, y_test))
print("number of features used: %d" % np.sum(logisticregression.coef_ != 0))
# Out:
# training set score: 0.776699
# test set score: 0.803571
# number of features used: 42

# %% [markdown]
# #### With L1-Lasso Regression

# %% [markdown]
# ##### Beam and Weight

# %%
df_bream = data[data['Species'] == 'Bream']

from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()

X = df_bream.Cross_Length.values.reshape(-1,1)
y = df_bream.Weight.values.reshape(-1,1)

# %%
#We must increase "max_iter" if not the model would warn us to increase it
from sklearn.linear_model import Lasso
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)

lasso100 = Lasso(alpha=10, max_iter=100).fit(X_train, y_train)
print("training set score: %f" % lasso100.score(X_train, y_train))
print("test set score: %f" % lasso100.score(X_test, y_test))
print("number of features used: %d" % np.sum(lasso100.coef_ != 0))
# Out:
# training set score: 0.938713
# test set score: 0.824171
# number of features used: 1

# %% [markdown]
# ##### Using all features

# %%
feature_names = ['Weight','Vertical_Length','Diagonal_Length','Cross_Length','Height','Width']
x = data[feature_names]
y = data['Species']

from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.25, random_state=42)
lr_l1 = LogisticRegression(C=100, penalty='l1', solver='liblinear').fit(x_train, y_train)#solver='liblinear' for small dataset
print("train accuracy of L1 logreg with 1: %f" % lr_l1.score(x_train, y_train))
print("test accuracy of L1 logreg with 1: %f"%  lr_l1.score(x_test, y_test))
print("number of features used: %d" % np.sum(lr_l1.coef_ != 0))
# Out:
# train accuracy of L1 logreg with 1: 0.974790
# test accuracy of L1 logreg with 1: 0.925000
# number of features used: 41

# %% [markdown]
# ### Decision Tree Regressor

# %% [markdown]
# **Without importing parameter estimator**

# %%
x = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.20, random_state=42)
tree = DecisionTreeRegressor(max_depth=10, random_state=0)

tree.fit(x_train, y_train)

print("accuracy on training set: %f" % tree.score(x_train, y_train))
print("accuracy on test set: %f" % tree.score(x_test, y_test))
# Out:
# accuracy on training set: 0.999838
# accuracy on test set: 0.944605

# %% [markdown]
# **Importing parameter estimator**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
xx = data.iloc[:, 2:].values
yy = data.iloc[:, 1].values

xx_train, xx_test, yy_train, yy_test = train_test_split(xx,yy,
                                                        test_size=0.20, random_state=42)

param_dist = {"max_depth": [2, 6], "max_features": [1,3,4,5,7,8,9], "min_samples_leaf": [1,3,4,5,6,7]}
tree1 = DecisionTreeRegressor(random_state = 1)
tree_cv = GridSearchCV(tree1, param_dist)
tree_cv.fit(x_train, y_train)

print(tree_cv.best_params_)
print(tree_cv.score(xx_test, yy_test))
print("accuracy on training set: %f" % tree_cv.score(xx_train, yy_train))
print("accuracy on test set: %f" % tree_cv.score(xx_test, yy_test))
# Out:
# {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 1}
# 0.9625325399191473
# accuracy on training set: 0.996894
# accuracy on test set: 0.962533

# %%
lahat_training = pd.DataFrame()
lahat_test = pd.DataFrame()
for seedN in range(1,50,1):
    X_train, X_test, y_train, y_test = train_test_split(XX, y, test_size=0.25, random_state=seedN)
    training_accuracy = []  
    test_accuracy = []
    maxdepth_settings = range(1, 15) # try n_neighbors from 1 to 10

    for depth in maxdepth_settings:   
        reg = DecisionTreeRegressor(random_state=0, max_depth=depth) # build the model 
        reg.fit(X_train, y_train) #clf = KNeighborsClassifier(n_neighbors=n_neighbors    
        training_accuracy.append(reg.score(X_train, y_train)) # record training set accuracy  
        test_accuracy.append(reg.score(X_test, y_test)) # record generalization accuracy    
    lahat_training[seedN]=training_accuracy
    lahat_test[seedN] = test_accuracy

# %%
fig = plt.figure(figsize=(15, 6))
plt.errorbar(maxdepth_settings, lahat_training.mean(axis=1),
             yerr=lahat_training.std(axis=1), label="training accuracy")
plt.errorbar(maxdepth_settings, lahat_test.mean(axis=1),
             yerr=lahat_test.std(axis=1), label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Max_Depth")
plt.legend()
bestdepth=np.argmax(lahat_test.mean(axis=1))+1
print("Highest Average Test Set Achieved = %f" % np.amax(lahat_test.mean(axis=1)))
print("Max_Depth = %d" %bestdepth )

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.20, random_state=42)
forest = RandomForestRegressor(n_estimators=4, random_state=42)

forest.fit(x_train, y_train)
print("accuracy on training set: %f" % forest.score(x_train, y_train))
print("accuracy on test set: %f" % forest.score(x_test, y_test))
# Out:
# accuracy on training set: 0.993304
# accuracy on test set: 0.949271

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.20, random_state=42)
param_grid = {'bootstrap': [True], 'max_depth': [3, 5, 10, None],
              'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15, 1000]}
rfr = RandomForestRegressor(random_state = 1)

g_search = GridSearchCV(estimator = rfr, param_grid = param_grid)

g_search.fit(x_train, y_train);

print(g_search.best_params_)
print(g_search.score(x_test, y_test))
print("accuracy on training set: %f" % g_search.score(x_train, y_train))
print("accuracy on test set: %f" % g_search.score(x_test, y_test))
# Out:
# {'bootstrap': True, 'max_depth': 10, 'n_estimators': 1000}
# 0.9719448905077278
# accuracy on training set: 0.996505
# accuracy on test set: 0.971945

# %% [markdown]
# ### Gradient Boosting Regressor

# %% [markdown]
# **Without importing parameter estimator**

# %%
from sklearn.ensemble import GradientBoostingRegressor
x = data.iloc[:, 2:].values
y = data.iloc[:, 1].values
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.25, random_state=42)

gbrt = GradientBoostingRegressor(learning_rate= 0.01, max_depth= 2)
gbrt.fit(x_train, y_train)

print("accuracy on training set: %f" % gbrt.score(x_train, y_train))
print("accuracy on test set: %f" % gbrt.score(x_test, y_test))
# Out:
# accuracy on training set: 0.814175
# accuracy on test set: 0.784513

# %% [markdown]
# **Importing parameter estimator**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

x = data.iloc[:, 2:].values
y = data.iloc[:, 1].values
    
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                        test_size=0.20, random_state=42)
GBR = GradientBoostingRegressor()

parameters = {'learning_rate': [0.01,0.02,0.03,0.04],
                  'subsample'    : [0.9, 0.5, 0.2, 0.1],
                  'n_estimators' : [100,500,1000, 1500],
                  'max_depth'    : [4,6,8,10]
                 }
grid_GBR = GridSearchCV(estimator=GBR, param_grid = parameters)
grid_GBR.fit(x_train, y_train)
print(grid_GBR.best_params_)
print(grid_GBR.score(x_test, y_test))
print("accuracy on training set: %f" % grid_GBR.score(x_train, y_train))
print("accuracy on test set: %f" % grid_GBR.score(x_test, y_test))
# Out:
# {'learning_rate': 0.04, 'max_depth': 6, 'n_estimators': 1000, 'subsample': 0.5}
# 0.9744370081356283
# accuracy on training set: 0.999919
# accuracy on test set: 0.974437

# %% [markdown]
# #### K-Nearest Neighbor Regression

# %%
x = data.iloc[:, 2:].values
y = data.iloc[:, 1].values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
parameters = {"n_neighbors": range(1, 100)}
gridsearch = GridSearchCV(KNeighborsRegressor(), parameters)
gridsearch.fit(x_train, y_train)
GridSearchCV(estimator=KNeighborsRegressor(),
             param_grid={'n_neighbors': range(1, 100),
                         'weights': ['uniform', 'distance']})
gridsearch.best_params_
# Out:
# {'n_neighbors': 1}

# %%
#split for train and test data
from sklearn.neighbors import KNeighborsRegressor
#
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42) #random state = reproducible and consistant
# Instantiate the model, set the number of neighbors to consider to 1:
reg = KNeighborsRegressor(n_neighbors=1)
# Fit the model using the training data and training targets:
reg.fit(x_train, y_train)
KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
metric_params=None, n_jobs=1, n_neighbors=1, p=2,
weights='uniform')
print('Regression Score', reg.score(x_test, y_test))
# Out:
# Regression Score 0.9646887700294853

# %%
reg.score
reg.predict(x_test)
training_accuracy = []  
test_accuracy = []
neighbors_settings = range(1, 10) 

for n_neighbors in neighbors_settings:   
    reg = KNeighborsRegressor(n_neighbors=n_neighbors) # build the model 
    reg.fit(x_train, y_train) #clf = KNeighborsClassifier(n_neighbors=n_neighbors    
    training_accuracy.append(reg.score(x_train, y_train)) # record training set accuracy  
    test_accuracy.append(reg.score(x_test, y_test)) # record generalization accuracy    
fig = plt.figure(figsize=(20, 6))
import pylab as plot
params = {'legend.fontsize': 20, 'legend.handlelength': 2}
plot.rcParams.update(params)
plt.plot(neighbors_settings, training_accuracy, label="training accuracy", color='blue', marker='o', linestyle='dashed', markersize=18)
plt.plot(neighbors_settings, test_accuracy, label="test accuracy",color='red', marker='^', linestyle='-', markersize=18)
plt.ylabel("Accuracy, $R^2$", fontsize=18)
plt.xlabel("n_neighbors",fontsize=18)
plt.legend()
pass

# %%
y_pred = g_search.predict(x_test)
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})

from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
r2 = metrics.r2_score(y_test,y_pred)
print("R-Squared:", r2)
# Out:
# Mean Absolute Error: 36.597467662337635
# Root Mean Squared Error: 56.86846675718406
# R-Squared: 0.9751968241572995

# %%
y_pred = g_search.predict(x_test)
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})

from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
r2 = metrics.r2_score(y_test,y_pred)
print("R-Squared:", r2)
# Out:
# Mean Absolute Error: 36.597467662337635
# Root Mean Squared Error: 56.86846675718406
# R-Squared: 0.9751968241572995

# %%
y_pred = reg.predict(x_test)
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})

from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
r2 = metrics.r2_score(y_test,y_pred)
print("R-Squared:", r2)
# Out:
# Mean Absolute Error: 57.25999999999999
# Root Mean Squared Error: 95.62585708483807
# R-Squared: 0.929868208167679

# %% [markdown]
# <table>
# <thead>
# <tr><th>Machine Learning Method</th><th>Test Accuracy</th><th>Feautures</th></tr>
# </thead>
# <tbody>
# <tr><td>L2-Ridge Regression</td><td>82.64%</td><td>1 Features</td></tr>
# <tr><td>L2-Ridge Regression</td><td>80.35%</td><td>42 features</td></tr>
# <tr><td>L1-Lasso Regression</td><td>82.41%</td><td>1 Features</td></tr>
# <tr><td>L1-Lasso Regression</td><td>97.50%</td><td>41 features</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Observation:
#
# Using L2-  Ridge Regression,  the model obtained 82.64% test accuracy, with one (1) feature. However, using 42 features, the model obtained 80.35% test accuracy.
#
# The test accuracy of L1-Lasso Regression is 82.41% using one feature with alpha = 10 while using 41 features the test accuracy is 95%.
#
# Therefore the best Logistic Regression is  L1-Lasso Regression using  41 features with alpha = 10 to predict the target value.

# %% [markdown]
# <table>
# <thead>
# <tr><th>Machine Learning Method</th><th>Estimator</th><th>Test Accuracy</th><th>Best Parameter</th></tr>
# </thead>
# <tbody>
# <tr><td>Linear Regression</td><td>None</td><td>82.64%</td><td>None</td></tr>
# <tr><td>Decision Tree Regressor</td><td>None</td><td>94.46%</td><td>max_depth=10, random_state=0</td></tr>
# <tr><td>Decision Tree Regressor</td><td>GridSearchCV</td><td>96.25%</td><td>max_depth= 6, max_features= 5, min_samples_leaf= 1</td></tr>
# <tr><td>K-Nearest Neighbor Regression</td><td>GridSearchCV</td><td>96.46%</td><td>'n_neighbors': 1</td></tr>
# <tr><td>Gradient Boosting Regressor</td><td>None</td><td>78.07%</td><td>learning_rate= 0.01, max_depth= 2</td></tr>
# <tr><td>Gradient Boosting Regressor</td><td>GridSearchCV</td><td>97.18%</td><td>'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 500, 'subsample': 0.5</td></tr>
# <tr><td>Random Forest Regressor</td><td>None</td><td>94.92%</td><td>n_estimators=4, random_state=42</td></tr>
# <tr><td>Random Forest Regressor</td><td>GridSearchCV</td><td>97.19%</td><td>'bootstrap': True, 'max_depth': 10, 'n_estimators': 1000</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Insights:
#
# Using Bream Cross_Length as feature adn Bream Weight as the target of **Linear Regression**, the model obtained  93.88% of R2 in training score while 82.65% in test score. This means that the model has good accuracy in predicting the target value.
#
# **Decision Tree Regressor:**
# The model obtained 99% in training score and 94% in test score. Using maximum depth of 10 This means the model is excellent predicting the target value.
# With the same Machine Learning method, using GridSearchCV to identify the best maximum depth which is 6, maximum features used is 5 and minimum sample of leaf is 1. The model obtained 96.25% test accuracy higher than the previous model. Therefore, using the best parameter can lesser outliers and gives better results.
#
# **KNN Regression:**
# The GridSearchCV is used to identify best parameter for  the model. Using nearest neighbors 1,test accuracy is 96.46%.  This result shows the parameters used is a best fit in building the model.
#
# **Gradient Boosting Regressor:**
# In using the Gradient Boosting Regressor, we attain a test accuracy score of 78.07%, but upon using with the GridSearchCV estimator, with n_estimator = 500, we can now see a higher test accuracy compared to previous result which resulted to a 97.18% test accuracy, where we conclude is the best accuracy.
#
# **Random Forest Regressor:**
# The model, which is Random Forest Regressor, achieves an accuracy of 94.92 % by selecting n_estimator equal to 4 with a random state of 42, and we can say that the model performs effectively. However, using a GridSearchCV estimator, we achieve a much better result with an accuracy of 97.19 percent with a max_depth of 10 and n_estimators of 1000 where we conclude that has the best accuracy.

# %% [markdown]
# ## Conclusion:
#
# By using both models, Classification and Regression, can effectively predict the value. As a result of Data Exploration, it was observed that Bream is the heaviest out of the seven fish. And in the other hand, Pike was the most popular fish out of all, we found out that the market price of Pike is cheap which everyone can afford to buy anytime. Most Machine Learning models used in the analysis,  Using Linear Regression model obtained 93.88% of R2 in training score while 82.65% in the test score. Decision Tree Regressor model obtained 99% in training score and 94% in test score while using GridSearchCV the model obtained 96.25% test accuracy higher than the previous model. KNN Regression, upon using GridSearchCV to identify the best parameter for the model, KNN model obtained 96.46% test accuracy which shows the parameters that we used is best fit in building the model. Gradient Boosting Regressor attain 78.07% accuracy test score but upon using GridSearchCV estimate with n_estimator = 500, the model attain 97.18% test accuracy which is the best accuracy. Random Forest Regressor, the model achieves 94.92 accuracy, but upon using GridSearchCV estimator the model obtained an accuracy of 97.19% where we conclude that has the best accuracy.
#
#
# In conclusion, Linear Regression can be applied to the Fish Market dataset to predict fish species with a given specification. It was more likely that linear regression would perform properly, which it did. However, because there was a strong linear correlation between training features, Lasso and Ridge also performed well.

# %% [markdown]
# ## Recommendation:
#
# In this project, we would like to apply using "QUEST" for the future research. QUEST stands for Quick, Unbiased, and Efficient Statistical Tree. It is one of the classification tree methods that produce two nodes per block. The basic linear regression model’s hyperparameter can be considered the learning rate. It is implemented as an SGDRegressor which updated the learning rate together with the weights. We think it is better to use hyperparameter  tuning for Ridge or Lasso in the future.

# %% [markdown]
# ### References:
#
# • https://www.kaggle.com/code/graciangelica/fish-market-eda-and-predictions/notebook </br>
# • https://en.m.wikipedia.org/wiki/Smelt_(fish) </br>
# • https://en.m.wikipedia.org/wiki/Esox </br>
# • https://en.m.wikipedia.org/wiki/Perch </br>
# • https://www.britannica.com/animal/bream </br>
# • https://www.britannica.com/animal/whitefish </br>
# • https://www.britannica.com/animal/roach </br>
# • https://en.wikipedia.org/wiki/Standard_weight_in_fish</br>
# • https://en.wikipedia.org/wiki/Fish_measurement

# %% [markdown]
# ## Sizes definition: For feature definitions
# **Weight** - The relative weight (Wr) of an individual fish is its actual weight divided by its standard weight, times 100%. A fish of "normal" weight has a relative weight of 100 percent. The relative weight of a fish does not indicate its health on a continuous scale from 0 -100%, however.
#
# **Length 1, length 2, length 3:**</BR>
# • **Standard length (SL)** is the length of a fish measured from the tip of the snout to the posterior end of the last vertebra or to the posterior end of the midlateral portion of the hypural plate. Simply put, this measurement excludes the length of the caudal (tail) fin.
#
# • **Total length (TL)** is the length of a fish measured from the tip of the snout to the tip of the longer lobe of the caudal fin, usually measured with the lobes compressed along the midline. It is a straight-line measure, not measured over the curve of the body.
#
# Standard length measurements are used with Teleostei (most bony fish), while total length measurements are used with Myxini (hagfish), Petromyzontiformes (lampreys), and (usually) Elasmobranchii (sharks and rays), as well as some other fishes.
# Total length measurements are used in slot limit and minimum landing size regulations.
#
# In addition, fishery biologists often use a third measure in fishes with forked tails:</BR>
# • **Fork length (FL)** is the length of a fish measured from the tip of the snout to the end of the middle caudal fin rays, and is used in fishes in which it is difficult to tell where the vertebral column ends.
